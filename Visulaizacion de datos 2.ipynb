# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2023-05-25T19:26:31.769793-03:00
#
# Python implementation: CPython
# Python version       : 3.10.9
# IPython version      : 8.10.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 140 Stepping 1, GenuineIntel
# CPU cores   : 8
# Architecture: 64bit

# %% [markdown]
# ### VISUALIZACION DE DATOS

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\54296\Desktop\Data Science\⁫Visualizacion de datos\boston_dataset.csv")

# %%
df.head()
# Out:
#          TOWN     LON      LAT  MEDV     CRIM    ZN  INDUS  CHAS    NOX  \
# 0      Nahant -70.955  42.2550  24.0  0.00632  18.0   2.31     0  0.538
# 1  Swampscott -70.950  42.2875  21.6  0.02731   0.0   7.07     0  0.469
# 2  Swampscott -70.936  42.2830  34.7  0.02729   0.0   7.07     0  0.469
# 3  Marblehead -70.928  42.2930  33.4  0.03237   0.0   2.18     0  0.458
# 4  Marblehead -70.922  42.2980  36.2  0.06905   0.0   2.18     0  0.458
#
#       RM   AGE     DIS  RAD  TAX  PTRATIO       B  LSTAT
# 0  6.575  65.2  4.0900    1  296     15.3  396.90   4.98
# 1  6.421  78.9  4.9671    2  242     17.8  396.90   9.14
# 2  7.185  61.1  4.9671    2  242     17.8  392.83   4.03
# 3  6.998  45.8  6.0622    3  222     18.7  394.63   2.94
# 4  7.147  54.2  6.0622    3  222     18.7  396.90   5.33

# %% [markdown]
# Renombrar las variables

# %%
df = df.rename(columns={
    "TOWN":"CIUDAD",
    "CRIM":"INDICE_CRIMEN",
    "ZN":"PCT_ZONA_RESIDENCIAL",
    "INDUS":"PCT_ZONA_INDUSTRIAL",
    "CHAS":"RIO_CHARLES",
    "NOX":"OXIDO_NITROSO_PPM",
    "RM":"N_HABITACIONES_MEDIO",
    "AGE":"PCT_CASAS_40S",
    "DIS_EMPLEO":"DISTANCIA_CENTRO_EMPLEO",
    "RAD":"DIS_AUTOPISTAS",
    "TAX":"CARGA_FISCAL",
    "PTRATIO":"RATIO_PROFESORES",
    "B":"PCT_NEGRA",
    "MEDV":"VALOR_MEDIANO",
    "LSTAT":"PCT_CLASE_BAJA"
})
df.head()
# Out:
#        CIUDAD     LON      LAT  VALOR_MEDIANO  INDICE_CRIMEN  \
# 0      Nahant -70.955  42.2550           24.0        0.00632
# 1  Swampscott -70.950  42.2875           21.6        0.02731
# 2  Swampscott -70.936  42.2830           34.7        0.02729
# 3  Marblehead -70.928  42.2930           33.4        0.03237
# 4  Marblehead -70.922  42.2980           36.2        0.06905
#
#    PCT_ZONA_RESIDENCIAL  PCT_ZONA_INDUSTRIAL  RIO_CHARLES  OXIDO_NITROSO_PPM  \
# 0                  18.0                 2.31            0              0.538
# 1                   0.0                 7.07            0              0.469
# 2                   0.0                 7.07            0              0.469
# 3                   0.0                 2.18            0              0.458
# 4                   0.0                 2.18            0              0.458
#
#    N_HABITACIONES_MEDIO  PCT_CASAS_40S     DIS  DIS_AUTOPISTAS  CARGA_FISCAL  \
# 0                 6.575           65.2  4.0900               1           296
# 1                 6.421           78.9  4.9671               2           242
# 2                 7.185           61.1  4.9671               2           242
# 3                 6.998           45.8  6.0622               3           222
# 4                 7.147           54.2  6.0622               3           222
#
#    RATIO_PROFESORES  PCT_NEGRA  PCT_CLASE_BAJA
# 0              15.3     396.90            4.98
# 1              17.8     396.90            9.14
# 2              17.8     392.83            4.03
# 3              18.7     394.63            2.94
# 4              18.7     396.90            5.33

# %% [markdown]
# ### CUSTOMIZAR PLOTS

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Podemos especificar el tamaño del grafico con el parametro figsize

# %%
df.plot(kind="scatter", x="N_HABITACIONES_MEDIO", y="VALOR_MEDIANO", marker="*",
        color="pink", figsize=(8,8))

plt.title("Relacion entre el numero de habitaciones y el valor de las viviendas")

plt.xlabel("Numero medio de habitaciones")

plt.ylabel("Valor mediano de las viviendas ($1000s)")
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0, 0.5, 'Valor mediano de las viviendas ($1000s)')

# %% [markdown]
# Se puede configurar el tamaño de los plots a nivel global cambiando los parametros de matplotlib

# %%
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (9,8)

# %%
df.plot(kind="scatter", x="N_HABITACIONES_MEDIO", y="VALOR_MEDIANO", marker="*", color="pink")

plt.title("Relacion entre el numero de habitaciones y el valor de las viviendas")

plt.xlabel("Numero medio de habitaciones")

plt.ylabel("Valor mediano de las viviendas ($1000s)")
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0, 0.5, 'Valor mediano de las viviendas ($1000s)')

# %% [markdown]
# Estilos

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Cambio los estilos para los futuros graficos

# %%
plt.style.use("seaborn-v0_8-pastel")

# %%
df.plot(kind="scatter", x="N_HABITACIONES_MEDIO", y="VALOR_MEDIANO")

plt.title("Relacion entre el numero de habitaciones y el valor de las viviendas")

plt.xlabel("Numero medio de habitaciones")

plt.ylabel("Valor mediano de las viviendas ($1000s)")
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0, 0.5, 'Valor mediano de las viviendas ($1000s)')

# %% [markdown]
# ### INTERACT

# %% [markdown]
# ipywidgets es un addon para juyter que permite embeber widgets de htlm interactivos en el notebook

# %%
conda install -c conda-forge ipywidgets
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\54296\anaconda3
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.5.7   |       h56e8100_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         294 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2023.5.7-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2023 | 145 KB    |            |   0%
#
# certifi-2023.5.7     | 149 KB    |            |   0%
#
# certifi-2023.5.7     | 149 KB    | #          |  11%
# ca-certificates-2023 | 145 KB    | #1         |  11%
#
# certifi-2023.5.7     | 149 KB    | ###2       |  32%
# ca-certificates-2023 | 145 KB    | ###3       |  33%
#
# certifi-2023.5.7     | 149 KB    | #####3     |  54%
# ca-certificates-2023 | 145 KB    | ####4      |  44%
#
# certifi-2023.5.7     | 149 KB    | #######5   |  75%
# ca-certificates-2023 | 145 KB    | #########9 |  99%
# ca-certificates-2023 | 145 KB    | ########## | 100%
#
# certifi-2023.5.7     | 149 KB    | ########## | 100%
#
# certifi-2023.5.7     | 149 KB    | ########## | 100%
#
#
# Note: you may need to restart the kernel to use updated packages.
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0

# %%
from ipywidgets import interact

# %%
@interact(col1=df.columns.tolist())
def grafico_variable(col1):
    df.plot.scatter(x=col1, y="VALOR_MEDIANO")
    plt.title("{} vs VALOR_MEDIANO".format(col1))
# Out:
# interactive(children=(Dropdown(description='col1', options=('CIUDAD', 'LON', 'LAT', 'VALOR_MEDIANO', 'INDICE_C…

# %% [markdown]
# ### MAPAS

# %%
# %matplotlib inline

# %%
df.plot(kind="scatter", x="LON", y="LAT")
# Out:
# <Axes: xlabel='LON', ylabel='LAT'>
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# ### CARTOPY

# %% [markdown]
# Es una libreria para hacer mapas

# %%
# !conda install -y -c conda-forge cartopy
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\54296\anaconda3
#
#   added / updated specs:
#     - cartopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cartopy-0.21.1             |  py310hb6e7958_0         1.6 MB
#     geos-3.8.0                 |       h33f27b4_0         905 KB
#     proj-8.2.1                 |       h5ed7ab8_0         2.4 MB
#     pyproj-3.4.1               |  py310h95ea4f9_0         391 KB
#     pyshp-2.3.1                |     pyhd8ed1ab_0         941 KB  conda-forge
#     shapely-2.0.1              |  py310h6c53999_0         396 KB
#     ------------------------------------------------------------
#                                            Total:         6.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cartopy            pkgs/main/win-64::cartopy-0.21.1-py310hb6e7958_0
#   geos               pkgs/main/win-64::geos-3.8.0-h33f27b4_0
#   proj               pkgs/main/win-64::proj-8.2.1-h5ed7ab8_0
#   pyproj             pkgs/main/win-64::pyproj-3.4.1-py310h95ea4f9_0
#   pyshp              conda-forge/noarch::pyshp-2.3.1-pyhd8ed1ab_0
#   shapely            pkgs/main/win-64::shapely-2.0.1-py310h6c53999_0
#
#
#
# Downloading and Extracting Packages
#
# proj-8.2.1           | 2.4 MB    |            |   0%
#
# pyproj-3.4.1         | 391 KB    |            |   0%
#
#
# pyshp-2.3.1          | 941 KB    |            |   0%
#
#
#
# cartopy-0.21.1       | 1.6 MB    |            |   0%
#
#
#
#
# shapely-2.0.1        | 396 KB    |            |   0%
#
#
#
#
#
# geos-3.8.0           | 905 KB    |            |   0%
#
# pyproj-3.4.1         | 391 KB    | 4          |   4%
#
#
#
# cartopy-0.21.1       | 1.6 MB    |            |   1%
#
# pyproj-3.4.1         | 391 KB    | #2         |  12%
#
#
#
#
# shapely-2.0.1        | 396 KB    | 4          |   4%
#
# pyproj-3.4.1         | 391 KB    | ##4        |  25%
#
# pyproj-3.4.1         | 391 KB    | ##8        |  29%
#
#
#
#
# shapely-2.0.1        | 396 KB    | #6         |  16%
#
#
# pyshp-2.3.1          | 941 KB    | 1          |   2%
# proj-8.2.1           | 2.4 MB    |            |   1%
#
# pyproj-3.4.1         | 391 KB    | ###2       |  33%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | 2          |   3%
# proj-8.2.1           | 2.4 MB    | 1          |   1%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | 5          |   6%
#
# pyproj-3.4.1         | 391 KB    | ####       |  41%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ##8        |  28%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ####       |  40%
#
#
# pyshp-2.3.1          | 941 KB    | 5          |   5%
# proj-8.2.1           | 2.4 MB    | 3          |   3%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | 6          |   7%
#
# pyproj-3.4.1         | 391 KB    | #####7     |  57%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ####8      |  49%
#
# pyproj-3.4.1         | 391 KB    | ######9    |  70%
#
#
#
#
# shapely-2.0.1        | 396 KB    | #####2     |  53%
#
#
# pyshp-2.3.1          | 941 KB    | 6          |   7%
# proj-8.2.1           | 2.4 MB    | 4          |   5%
# proj-8.2.1           | 2.4 MB    | 5          |   5%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #          |  11%
#
#
#
#
# shapely-2.0.1        | 396 KB    | #####6     |  57%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ######     |  61%
# proj-8.2.1           | 2.4 MB    | 7          |   7%
#
#
# pyshp-2.3.1          | 941 KB    | #5         |  15%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #1         |  12%
#
# pyproj-3.4.1         | 391 KB    | #######7   |  78%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ######4    |  65%
#
#
# pyshp-2.3.1          | 941 KB    | #6         |  17%
# proj-8.2.1           | 2.4 MB    | 7          |   8%
#
# pyproj-3.4.1         | 391 KB    | ########5  |  86%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #4         |  15%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ######8    |  69%
#
#
# pyshp-2.3.1          | 941 KB    | ##2        |  22%
#
# pyproj-3.4.1         | 391 KB    | #########4 |  94%
# proj-8.2.1           | 2.4 MB    | 9          |   9%
#
#
# pyshp-2.3.1          | 941 KB    | ##8        |  29%
#
#
#
#
# shapely-2.0.1        | 396 KB    | #######2   |  73%
#
# pyproj-3.4.1         | 391 KB    | ########## | 100%
#
# pyproj-3.4.1         | 391 KB    | ########## | 100%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #6         |  17%
# proj-8.2.1           | 2.4 MB    | #1         |  11%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #8         |  19%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ########4  |  85%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #9         |  20%
# proj-8.2.1           | 2.4 MB    | #1         |  12%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | 1          |   2%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##         |  21%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | 5          |   5%
# proj-8.2.1           | 2.4 MB    | #2         |  13%
#
#
# pyshp-2.3.1          | 941 KB    | ###2       |  32%
#
#
#
#
# shapely-2.0.1        | 396 KB    | #########7 |  97%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##1        |  22%
# proj-8.2.1           | 2.4 MB    | #3         |  13%
#
#
# pyshp-2.3.1          | 941 KB    | ###3       |  34%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ########## | 100%
#
#
#
#
# shapely-2.0.1        | 396 KB    | ########## | 100%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##2        |  23%
#
#
# pyshp-2.3.1          | 941 KB    | ###7       |  37%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #2         |  12%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##3        |  24%
# proj-8.2.1           | 2.4 MB    | #3         |  14%
#
#
# pyshp-2.3.1          | 941 KB    | ###9       |  39%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #5         |  16%
# proj-8.2.1           | 2.4 MB    | #4         |  14%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ##2        |  23%
#
#
# pyshp-2.3.1          | 941 KB    | ####       |  41%
# proj-8.2.1           | 2.4 MB    | #5         |  15%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##4        |  25%
#
#
# pyshp-2.3.1          | 941 KB    | ####2      |  42%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##6        |  27%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ##4        |  25%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ###        |  30%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##7        |  28%
# proj-8.2.1           | 2.4 MB    | #5         |  16%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ###3       |  34%
#
#
# pyshp-2.3.1          | 941 KB    | ####4      |  44%
# proj-8.2.1           | 2.4 MB    | #7         |  17%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ##8        |  29%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ###7       |  37%
#
#
# pyshp-2.3.1          | 941 KB    | ####9      |  49%
# proj-8.2.1           | 2.4 MB    | #7         |  18%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ####       |  41%
#
#
# pyshp-2.3.1          | 941 KB    | #####      |  51%
# proj-8.2.1           | 2.4 MB    | #8         |  18%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###        |  31%
#
#
# pyshp-2.3.1          | 941 KB    | #####2     |  53%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ####4      |  44%
# proj-8.2.1           | 2.4 MB    | #9         |  19%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###1       |  32%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ####5      |  46%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ####7      |  48%
# proj-8.2.1           | 2.4 MB    | #9         |  20%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###2       |  33%
#
#
# pyshp-2.3.1          | 941 KB    | #####4     |  54%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ####9      |  50%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###3       |  34%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #####1     |  51%
#
#
# pyshp-2.3.1          | 941 KB    | #####7     |  58%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #####3     |  53%
# proj-8.2.1           | 2.4 MB    | ##         |  20%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###4       |  35%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #####4     |  55%
# proj-8.2.1           | 2.4 MB    | ##1        |  21%
#
#
# pyshp-2.3.1          | 941 KB    | #####9     |  59%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###5       |  36%
# proj-8.2.1           | 2.4 MB    | ##1        |  22%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #####6     |  57%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###6       |  37%
#
#
# pyshp-2.3.1          | 941 KB    | ######1    |  61%
#
#
# pyshp-2.3.1          | 941 KB    | ######2    |  63%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###7       |  38%
# proj-8.2.1           | 2.4 MB    | ##2        |  22%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ######1    |  62%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ######7    |  67%
# proj-8.2.1           | 2.4 MB    | ##3        |  23%
#
#
# pyshp-2.3.1          | 941 KB    | ######4    |  65%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ###8       |  39%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ######8    |  69%
#
#
# pyshp-2.3.1          | 941 KB    | ######7    |  68%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####       |  41%
# proj-8.2.1           | 2.4 MB    | ##4        |  24%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #######    |  71%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####1      |  42%
# proj-8.2.1           | 2.4 MB    | ##5        |  25%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #######2   |  72%
#
#
# pyshp-2.3.1          | 941 KB    | ######9    |  70%
# proj-8.2.1           | 2.4 MB    | ##5        |  26%
#
#
# pyshp-2.3.1          | 941 KB    | #######3   |  73%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####2      |  43%
# proj-8.2.1           | 2.4 MB    | ##6        |  26%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #######6   |  76%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ########1  |  81%
# proj-8.2.1           | 2.4 MB    | ##6        |  27%
#
#
# pyshp-2.3.1          | 941 KB    | #######4   |  75%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####3      |  43%
#
#
# pyshp-2.3.1          | 941 KB    | #######6   |  76%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####5      |  45%
# proj-8.2.1           | 2.4 MB    | ##7        |  28%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ########3  |  83%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ########6  |  87%
#
#
# pyshp-2.3.1          | 941 KB    | #######8   |  78%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####6      |  46%
# proj-8.2.1           | 2.4 MB    | ##8        |  28%
#
#
# pyshp-2.3.1          | 941 KB    | #######9   |  80%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####7      |  47%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #########  |  90%
# proj-8.2.1           | 2.4 MB    | ##8        |  29%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####8      |  48%
#
#
# pyshp-2.3.1          | 941 KB    | ########1  |  82%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #########1 |  92%
# proj-8.2.1           | 2.4 MB    | ##9        |  30%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ####9      |  49%
#
#
# pyshp-2.3.1          | 941 KB    | ########3  |  83%
# proj-8.2.1           | 2.4 MB    | ###        |  30%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #########3 |  94%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #########5 |  95%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####      |  50%
# proj-8.2.1           | 2.4 MB    | ###        |  31%
#
#
# pyshp-2.3.1          | 941 KB    | ########4  |  85%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | #########7 |  97%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####1     |  51%
# proj-8.2.1           | 2.4 MB    | ###1       |  32%
#
#
# pyshp-2.3.1          | 941 KB    | ########6  |  87%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ########## | 100%
#
#
#
#
#
# geos-3.8.0           | 905 KB    | ########## | 100%
# proj-8.2.1           | 2.4 MB    | ###2       |  32%
#
#
# pyshp-2.3.1          | 941 KB    | #########  |  90%
# proj-8.2.1           | 2.4 MB    | ###2       |  33%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####3     |  53%
#
#
# pyshp-2.3.1          | 941 KB    | #########1 |  92%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####4     |  54%
# proj-8.2.1           | 2.4 MB    | ###3       |  34%
#
#
# pyshp-2.3.1          | 941 KB    | #########3 |  93%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####5     |  55%
#
#
# pyshp-2.3.1          | 941 KB    | #########5 |  95%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####6     |  56%
# proj-8.2.1           | 2.4 MB    | ###4       |  34%
# proj-8.2.1           | 2.4 MB    | ###5       |  36%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####7     |  57%
#
#
# pyshp-2.3.1          | 941 KB    | #########6 |  97%
# proj-8.2.1           | 2.4 MB    | ###6       |  36%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####8     |  58%
#
#
# pyshp-2.3.1          | 941 KB    | #########8 |  99%
# proj-8.2.1           | 2.4 MB    | ###6       |  37%
#
#
# pyshp-2.3.1          | 941 KB    | ########## | 100%
#
#
# pyshp-2.3.1          | 941 KB    | ########## | 100%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #####9     |  59%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######1    |  61%
# proj-8.2.1           | 2.4 MB    | ###7       |  38%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######2    |  62%
# proj-8.2.1           | 2.4 MB    | ###8       |  39%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######3    |  63%
# proj-8.2.1           | 2.4 MB    | ###9       |  39%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######5    |  65%
# proj-8.2.1           | 2.4 MB    | ####       |  41%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######6    |  66%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######7    |  67%
# proj-8.2.1           | 2.4 MB    | ####1      |  41%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######8    |  68%
# proj-8.2.1           | 2.4 MB    | ####2      |  42%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ######9    |  69%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #######1   |  71%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #######2   |  72%
# proj-8.2.1           | 2.4 MB    | ####2      |  43%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #######3   |  73%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #######4   |  74%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #######6   |  76%
# proj-8.2.1           | 2.4 MB    | ####4      |  44%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #######8   |  78%
# proj-8.2.1           | 2.4 MB    | ####4      |  45%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ########   |  80%
# proj-8.2.1           | 2.4 MB    | ####5      |  45%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ########3  |  83%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ########6  |  87%
# proj-8.2.1           | 2.4 MB    | ####6      |  46%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ########8  |  89%
# proj-8.2.1           | 2.4 MB    | ####6      |  47%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #########1 |  92%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #########3 |  94%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #########5 |  96%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #########7 |  98%
# proj-8.2.1           | 2.4 MB    | ####7      |  47%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | #########9 | 100%
# proj-8.2.1           | 2.4 MB    | ####8      |  48%
# proj-8.2.1           | 2.4 MB    | ####8      |  49%
#
#
#
# cartopy-0.21.1       | 1.6 MB    | ########## | 100%
# proj-8.2.1           | 2.4 MB    | ####9      |  49%
# proj-8.2.1           | 2.4 MB    | #####      |  50%
# proj-8.2.1           | 2.4 MB    | #####      |  51%
# proj-8.2.1           | 2.4 MB    | #####1     |  51%
# proj-8.2.1           | 2.4 MB    | #####1     |  52%
# proj-8.2.1           | 2.4 MB    | #####2     |  53%
# proj-8.2.1           | 2.4 MB    | #####3     |  53%
# proj-8.2.1           | 2.4 MB    | #####3     |  54%
# proj-8.2.1           | 2.4 MB    | #####4     |  55%
# proj-8.2.1           | 2.4 MB    | #####5     |  55%
# proj-8.2.1           | 2.4 MB    | #####5     |  56%
# proj-8.2.1           | 2.4 MB    | #####6     |  57%
# proj-8.2.1           | 2.4 MB    | #####7     |  58%
# proj-8.2.1           | 2.4 MB    | #####9     |  60%
# proj-8.2.1           | 2.4 MB    | ######     |  61%
# proj-8.2.1           | 2.4 MB    | ######1    |  62%
# proj-8.2.1           | 2.4 MB    | ######2    |  63%
# proj-8.2.1           | 2.4 MB    | ######3    |  63%
# proj-8.2.1           | 2.4 MB    | ######5    |  65%
# proj-8.2.1           | 2.4 MB    | ######6    |  66%
# proj-8.2.1           | 2.4 MB    | ######7    |  68%
# proj-8.2.1           | 2.4 MB    | ######9    |  69%
# proj-8.2.1           | 2.4 MB    | #######    |  70%
# proj-8.2.1           | 2.4 MB    | #######1   |  72%
# proj-8.2.1           | 2.4 MB    | #######3   |  73%
# proj-8.2.1           | 2.4 MB    | #######5   |  75%
# proj-8.2.1           | 2.4 MB    | #######6   |  76%
# proj-8.2.1           | 2.4 MB    | #######8   |  78%
# proj-8.2.1           | 2.4 MB    | #######9   |  80%
# proj-8.2.1           | 2.4 MB    | ########1  |  82%
# proj-8.2.1           | 2.4 MB    | ########2  |  83%
# proj-8.2.1           | 2.4 MB    | ########4  |  84%
# proj-8.2.1           | 2.4 MB    | ########8  |  88%
# proj-8.2.1           | 2.4 MB    | #########1 |  91%
# proj-8.2.1           | 2.4 MB    | #########4 |  94%
# proj-8.2.1           | 2.4 MB    | #########6 |  96%
# proj-8.2.1           | 2.4 MB    | #########7 |  97%
# proj-8.2.1           | 2.4 MB    | #########8 |  99%
# proj-8.2.1           | 2.4 MB    | ########## | 100%
# proj-8.2.1           | 2.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0

# %%
import cartopy.crs as ccrs
from cartopy.io import img_tiles

# %%
# %matplotlib inline

# %%
df.VALOR_MEDIANO.plot(kind="kde");

# %%
primer_quintil = df.VALOR_MEDIANO.quantile(0.2)
primer_quintil
# Out:
# 15.3

# %%
cuarto_quintil = df.VALOR_MEDIANO.quantile(0.8)
cuarto_quintil
# Out:
# 28.2

# %%
# %matplotlib notebook

# %%
imagery = img_tiles.GoogleTiles()

ax = plt.axes(projection=imagery.crs)

#x0, x1, y0, y1
limites_mapa = (-71.38 ,-70.77,42.03 , 42.47)
ax.set_extent(limites_mapa)

ax.add_image(imagery, 10)
df_primer_qt = df[df.VALOR_MEDIANO<primer_quintil]
df_ultimo_qt = df[df.VALOR_MEDIANO>cuarto_quintil]

plt.plot(df_primer_qt.LON, df_primer_qt.LAT, transform=ccrs.Geodetic(), 
         marker='.', markersize=10, color="red",  linewidth=0, alpha=0.5)

plt.plot(df_ultimo_qt.LON, df_ultimo_qt.LAT, transform=ccrs.Geodetic(),
         marker='.', markersize=10, color="green",  linewidth=0, alpha=0.5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# %matplotlib inline

# %% [markdown]
# ### LIBRERIAS RECOMENDADAS

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Una de las principales ventajas de Seaborn es que permiten hacer graficos cientificos de forma facil

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.12.2'

# %%
sns.lmplot(x="N_HABITACIONES_MEDIO", y="VALOR_MEDIANO", data=df)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
sns.heatmap(df.corr());
# Out:
# C:\Users\54296\AppData\Local\Temp\ipykernel_9256\2460615548.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr());

# %% [markdown]
# ## Bokeh

# %% [markdown]
# Es una libreria imperativa.

# %%
conda install bokeh
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\54296\anaconda3
#
#   added / updated specs:
#     - bokeh
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2023.5.7           |  py310haa95532_0         153 KB
#     ------------------------------------------------------------
#                                            Total:         153 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2023.5.7~ --> pkgs/main::ca-certificates-2023.01.10-haa95532_0
#   certifi            conda-forge/noarch::certifi-2023.5.7-~ --> pkgs/main/win-64::certifi-2023.5.7-py310haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2023.5.7     | 153 KB    |            |   0%
# certifi-2023.5.7     | 153 KB    | #          |  10%
# certifi-2023.5.7     | 153 KB    | ######2    |  63%
# certifi-2023.5.7     | 153 KB    | #########4 |  94%
# certifi-2023.5.7     | 153 KB    | ########## | 100%
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0

# %%
import bokeh.plotting as bk

bk.output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
df.INDICE_CRIMEN
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: INDICE_CRIMEN, Length: 506, dtype: float64

# %%
df["CRIMEN_QUINTIL"] = pd.qcut(df.INDICE_CRIMEN, 5)

# %%
df.CRIMEN_QUINTIL.cat.categories
# Out:
# IntervalIndex([(0.00532, 0.0642], (0.0642, 0.15], (0.15, 0.55], (0.55, 5.581], (5.581, 88.976]], dtype='interval[float64, right]')

# %%
from bokeh.palettes import brewer

colors = brewer["Spectral"][len(df.CRIMEN_QUINTIL.unique())]
colors
# Out:
# ('#2b83ba', '#abdda4', '#ffffbf', '#fdae61', '#d7191c')

# %%
p = bk.figure(
plot_width=600,
    plot_height=600,
    title="Habitaciones vs Valor vivienda vs crimen"
)

for i, quintil in enumerate(df.CRIMEN_QUINTIL.cat.categories):
    df_q = df[df.CRIMEN_QUINTIL==quintil]
    p.scatter(df_q.N_HABITACIONES_MEDIO, df_q.VALOR_MEDIANO, color=colors[i],
             legend_label="({}-{})".format(quintil.left, quintil.right)
             )
    
bk.show(p);
# Out:
#   <div class="bk-root" id="4dfb47da-0626-44ce-a19e-25d30be04eaa" data-root-id="1003"></div>

# %%
import numpy as np

hist, edges = np.histogram(df.VALOR_MEDIANO, bins=20)

# %%
hist
# Out:
# array([ 9, 12, 18, 36, 41, 41, 84, 71, 72, 12, 23, 18, 17, 14,  6,  1,  5,
#         5,  2, 19], dtype=int64)

# %%
edges
# Out:
# array([ 5.  ,  7.25,  9.5 , 11.75, 14.  , 16.25, 18.5 , 20.75, 23.  ,
#        25.25, 27.5 , 29.75, 32.  , 34.25, 36.5 , 38.75, 41.  , 43.25,
#        45.5 , 47.75, 50.  ])

# %%
p1 = bk.figure(title="Histograma valor viviendas", tools="save,hover", background_fill_color="#E8DDCB")



p1.quad(top=hist,bottom=0, left=edges[:-1], right=edges[1:], fill_color="#026560")

bk.show(p1)
# Out:
#   <div class="bk-root" id="dfef5032-8109-412c-8e84-6cc694807167" data-root-id="1250"></div>

# %% [markdown]
# ## Altair

# %% [markdown]
# Es una libreria declarativa

# %%
conda install -c conda-forge altair vega_datasets
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\54296\anaconda3
#
#   added / updated specs:
#     - altair
#     - vega_datasets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-5.0.0               |     pyhd8ed1ab_0         363 KB  conda-forge
#     vega_datasets-0.9.0        |     pyhd3deb0d_0         179 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         543 KB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-5.0.0-pyhd8ed1ab_0
#   vega_datasets      conda-forge/noarch::vega_datasets-0.9.0-pyhd3deb0d_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2023.5.7-h56e8100_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/win-64::certifi-2023.5.7-py~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# vega_datasets-0.9.0  | 179 KB    |            |   0%
#
# altair-5.0.0         | 363 KB    |            |   0%
# vega_datasets-0.9.0  | 179 KB    | 8          |   9%
# vega_datasets-0.9.0  | 179 KB    | #7         |  18%
# vega_datasets-0.9.0  | 179 KB    | ###5       |  36%
#
# altair-5.0.0         | 363 KB    | 4          |   4%
# vega_datasets-0.9.0  | 179 KB    | #######1   |  71%
#
# altair-5.0.0         | 363 KB    | #3         |  13%
# vega_datasets-0.9.0  | 179 KB    | #########8 |  98%
# vega_datasets-0.9.0  | 179 KB    | ########## | 100%
#
# altair-5.0.0         | 363 KB    | #7         |  18%
#
# altair-5.0.0         | 363 KB    | ###9       |  40%
#
# altair-5.0.0         | 363 KB    | #####2     |  53%
#
# altair-5.0.0         | 363 KB    | ######6    |  66%
#
# altair-5.0.0         | 363 KB    | #########6 |  97%
#
# altair-5.0.0         | 363 KB    | ########## | 100%
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0

# %%
from altair import Chart, Color, Scale

# %%
df['CRIMEN_QUINTIL_STR'] = df.CRIMEN_QUINTIL.astype(str)

# %%
chart = Chart(df[['N_HABITACIONES_MEDIO','VALOR_MEDIANO','CRIMEN_QUINTIL_STR']])

scale = Scale(range=['#996666', '#b34d4d', '#cc3333','#e61919','#ff0000'], type='ordinal')

chart.mark_point().encode(
    x="N_HABITACIONES_MEDIO",
    y="VALOR_MEDIANO",
    color=Color("CRIMEN_QUINTIL_STR", scale=scale)

)
# Out:
# alt.Chart(...)
